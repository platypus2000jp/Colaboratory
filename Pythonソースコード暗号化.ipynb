# %% [markdown]
# <a href="https://colab.research.google.com/github/platypus2000jp/Colaboratory/blob/main/Python%E3%82%BD%E3%83%BC%E3%82%B9%E3%82%B3%E3%83%BC%E3%83%89%E6%9A%97%E5%8F%B7%E5%8C%96.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# prompt: Pythonファイルをアップロードします。

from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
# Out:
#      <input type="file" id="files-75ace1b9-3476-4263-9733-3cccc9ff78fc" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-75ace1b9-3476-4263-9733-3cccc9ff78fc">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# prompt: アップロードされたPythonソースコードを暗号化します。PyArmorを使用してください。注意、複合化できません。

# !pip install pyarmor

import os

for fn in uploaded.keys():
  # 暗号化対象のファイル名を取得
  file_name = fn

  # 出力ディレクトリを指定
  output_dir = "encrypted_code"
  if not os.path.exists(output_dir):
    os.makedirs(output_dir)

  # PyArmorを使って暗号化
  # !pyarmor obfuscate {file_name} --output {output_dir} --no-runtime


print("暗号化が完了しました。")
print(f"暗号化されたファイルは {output_dir} に格納されています。")

# %%
# prompt: 暗号化されたファイルに名前を付けて保存し、ダウンロードします。

import shutil
import os

# 暗号化されたファイルのパスを取得
encrypted_file_path = os.path.join("encrypted_code", os.listdir("encrypted_code")[0])

# ダウンロードするファイル名を設定
download_file_name = "encrypted_file.zip"

# ファイルをZIP圧縮
shutil.make_archive("encrypted_file", 'zip', "encrypted_code")

# ファイルをダウンロード
files.download(download_file_name)
